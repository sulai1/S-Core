# %%
id = XFkzRNyygfk
from youtube.yt_api import YoutubeApi

yt = YoutubeApi()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 id = AtqRXVdVVCc
#       2 y
#
# NameError: name 'AtqRXVdVVCc' is not defined
